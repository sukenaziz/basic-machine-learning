# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
print("Numpy:",np.__version__)
print("Pandas:",pd.__version__)
print("Matplotlb:",matplotlib.__version__)
# Out:
# ('Numpy:', '1.16.4')
# ('Numpy:', u'0.24.2')
# ('Numpy:', '2.2.4')

# %%
df_titanic = pd.read_csv('dataset/titanic.csv')
df_titanic
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# 5           0       3                                    Mr. James Moran
# 6           0       1                             Mr. Timothy J McCarthy
# 7           0       3                      Master. Gosta Leonard Palsson
# 8           1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9           1       2                 Mrs. Nicholas (Adele Achem) Nasser
# 10          1       3                     Miss. Marguerite Rut Sandstrom
# 11          1       1                            Miss. Elizabeth Bonnell
# ...

# %%
df_titanic.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
df_titanic.tail()
# Out:
#      Survived  Pclass                            Name     Sex   Age  \
# 882         0       2            Rev. Juozas Montvila    male  27.0
# 883         1       1     Miss. Margaret Edith Graham  female  19.0
# 884         0       3  Miss. Catherine Helen Johnston  female   7.0
# 885         1       1            Mr. Karl Howell Behr    male  26.0
# 886         0       3              Mr. Patrick Dooley    male  32.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard   Fare
# 882                        0                        0  13.00
# 883                        0                        0  30.00
# 884                        1                        2  23.45
# 885                        0                        0  30.00
# 886                        0                        0   7.75

# %%
df_titanic.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
# 5         0       3                                    Mr. James Moran
# 6         0       1                             Mr. Timothy J McCarthy
# 7         0       3                      Master. Gosta Leonard Palsson
# 8         1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9         1       2                 Mrs. Nicholas (Adele Achem) Nasser
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# ...

# %%
df_titanic.tail(50)
# Out:
#      Survived  Pclass                                               Name  \
# 837         0       2                            Mr. Thomas Charles Mudd
# 838         1       1                             Miss. Augusta Serepeca
# 839         0       3                          Mr. Peter L Lemberopolous
# 840         0       3                                 Mr. Jeso Culumovic
# 841         0       3                                 Mr. Anthony Abbing
# 842         0       3                            Mr. Douglas Bullen Sage
# 843         0       3                                  Mr. Marin Markoff
# 844         0       2                                   Rev. John Harper
# 845         1       1        Mrs. Samuel L (Edwiga Grabowska) Goldenberg
# 846         0       3             Master. Sigvard Harald Elias Andersson
# 847         0       3                                 Mr. Johan Svensson
# 848         0       3                             Miss. Nourelain Boulos
# ...

# %% [markdown]
# #### Change Colum Name

# %%
df_titnic.rename(columns=newcolumn)

# %% [markdown]
# #### Check Value

# %%
print('Total rows:',df_titanic.shape[0])
print('Total columns:',df_titanic.shape[1])
# Out:
# ('Total rows:', 887)
# ('Total columns:', 8)

# %%
df_titanic.isnull().any()
# Out:
# Survived                   False
# Pclass                     False
# Name                       False
# Sex                        False
# Age                        False
# Siblings/Spouses Aboard    False
# Parents/Children Aboard    False
# Fare                       False
# dtype: bool

# %% [markdown]
# #### DATA TYPE

# %%
df_titanic.dtypes
# Out:
# Survived                     int64
# Pclass                       int64
# Name                        object
# Sex                         object
# Age                        float64
# Siblings/Spouses Aboard      int64
# Parents/Children Aboard      int64
# Fare                       float64
# dtype: object

# %%
df_titanic[['Age','Sex']]
# Out:
#       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# 5    27.0    male
# 6    54.0    male
# 7     2.0    male
# 8    27.0  female
# 9    14.0  female
# 10    4.0  female
# 11   58.0  female
# 12   20.0    male
# 13   39.0    male
# 14   14.0  female
# 15   55.0  female
# 16    2.0    male
# 17   23.0    male
# 18   31.0  female
# 19   22.0  female
# 20   35.0    male
# 21   34.0    male
# 22   15.0  female
# 23   28.0    male
# 24    8.0  female
# 25   38.0  female
# 26   26.0    male
# 27   19.0    male
# 28   24.0  female
# 29   23.0    male
# ..    ...     ...
# 857  21.0    male
# 858  48.0  female
# 859  14.0  female
# 860  24.0    male
# 861  42.0  female
# 862  27.0  female
# 863  31.0    male
# 864  23.0    male
# 865   4.0    male
# 866  26.0    male
# 867  47.0  female
# 868  33.0    male
# 869  47.0    male
# 870  28.0  female
# 871  15.0  female
# 872  20.0    male
# 873  19.0    male
# 874  23.0    male
# ...

# %%
df_titanic[['Age']].
